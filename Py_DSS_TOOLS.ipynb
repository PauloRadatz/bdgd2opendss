# %%
! pip install py-dss-interface
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.0/15.0 MB 58.4 MB/s eta 0:00:00
# ...

# %%
! pip install py-dss-toolkit
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.3/101.3 kB 1.9 MB/s eta 0:00:00
# ...

# %%
import os
import py_dss_interface
from py_dss_toolkit import dss_tools

# %%
dss = py_dss_interface.DSS()
dss_tools.update_dss(dss)

# %%
dss.dssinterface.datapath
# Out:
# '/usr/local/lib/python3.12/dist-packages/py_dss_interface/opendss_official/linux/google_colab/'

# %%
path = '/content/drive/MyDrive/Colab_Notebooks/UNIFAP/Rede_multi_DG/Master_lvdn.dss'
caminho = os.path.join(path)
print(caminho)
# Out:
# /content/drive/MyDrive/Colab_Notebooks/UNIFAP/Rede_multi_DG/Master_lvdn.dss

# %%
dss.text(f"compile {caminho}")
#
#print(dss.circuit.total_power)
# Out:
# ''

# %%
dss.text("solve")

# %%
dss.loads.names

# %%
dss_tools.simulation.solve_snapshot(max_control_iter=20)

# %%
df = dss_tools.results.summary_df
df
# Out:
#                     Results
# P feeder (kW)     31.641388
# Q feeder (kvar)   10.346370
# P losses (kW)      0.641290
# Q losses (kvar)    0.157131
# max voltage (pu)   1.019992
# min voltage (pu)   1.013328

# %%
mag_voltage_ln_nodes_df = dss_tools.results.voltage_ln_nodes[0]
angle_voltage_ln_nodes_df = dss_tools.results.voltage_ln_nodes[1]
mag_voltage_ln_nodes_df.head()
# Out:
#                      node1     node2     node3
# sourcebus         1.019991  1.019992  1.019992
# bus_mg1_t1        1.018215  1.018376  1.018377
# bus_mg1_t1_f1_b1  1.018183  1.018349  1.018350
# bus_mg1_t1_f2_b1  1.018215  1.018376  1.018377
# bus_mg1_t1_f3_b1  1.018215  1.018376  1.018377

# %%
dss_tools.static_view.voltage_profile()
